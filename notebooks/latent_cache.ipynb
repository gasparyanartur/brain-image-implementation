# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import logging

from pathlib import Path

import dotenv

import torch
from torchvision.transforms.v2 import Compose
from torchvision.transforms.v2 import GaussianBlur, Compose

from huggingface_hub import login


from brain_image.data import load_image_from_path
from brain_image.configs import get_device
from brain_image.model import NICEModel
from brain_image.utils import setup

setup()

# %%
import hashlib


img_path1 = Path("data/things-eeg2/imgs/test_images/00001_aircraft_carrier/aircraft_carrier_06s.jpg")
img_path2 = Path("data/things-eeg2/imgs/test_images/00003_backscratcher/backscratcher_01b.jpg")

h1 = encode_keys(str(img_path1), "t1")
h2 = encode_keys(str(img_path1), "t2")

print(h1, h2)
# Out:
# 0753e82419a6264e44a5e5054f85364eb1c2dca4 89c2d38a108b58e880c173c63579303290b51b22

# %%
from pathlib import Path




tcache = TensorCache()

tcache.save_tensor(torch.randn(10, 10), "test", "test2")
tcache.load_tensor("test", "test2")
# Out:
# tensor([[ 2.3885,  0.6177, -0.3660, -0.8004, -0.4976, -0.9734,  0.3116, -0.0731,
#          -1.1214,  0.3600],
#         [-0.7714, -2.4663, -0.2479, -0.9366, -0.1366, -0.3735,  1.0506,  0.3373,
#           0.8230, -0.1066],
#         [-0.2351, -0.7864,  1.4625,  0.7750, -0.5836, -0.4408,  0.0582,  0.2787,
#          -1.4034,  0.2227],
#         [-0.0664,  1.6273,  0.0221, -0.3224,  1.0492, -1.5867,  0.3744, -0.1450,
#          -2.0024, -0.3577],
#         [-1.0026, -0.7153,  0.2713,  0.3606, -0.1581,  0.3129,  1.1587,  0.1351,
#          -1.5712,  1.9995],
#         [ 0.3241, -0.2928,  1.5529, -0.2565,  0.7695,  0.1665,  0.4676,  0.9046,
#          -0.9456, -0.8536],
#         [-2.1230,  1.9690, -0.5281, -0.9436,  1.8971,  0.3106,  1.6254, -0.1457,
#           1.9623, -0.6309],
#         [ 0.1092, -0.8690,  0.8241,  0.8008,  1.0999, -2.7823,  0.1864,  0.4581,
#          -1.1329,  0.9503],
#         [ 1.8120, -0.9396,  0.4503, -0.4244, -0.6814, -0.4350, -0.9971, -0.2791,
# ...
