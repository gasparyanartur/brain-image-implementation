# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from pathlib import Path 

rel_path = Path("experiments/comm-sweep-medium/comm-sweep-medium/260130225904tdexld-slurmarr15339793_3/version_0/checkpoints/train_comm-epoch_20-val-loss_4.0591.ckpt")

checkpoint = torch.load(rel_path, map_location="cpu")

checkpoint.keys()
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers', 'hparams_name', 'hyper_parameters'])

# %%
checkpoint["hyper_parameters"]
# Out:
# {'config': {'max_epochs': 30,
#   'seed': 4,
#   'log_on_step': False,
#   'img_encoder': 'unaligned_synclr_vitb16',
#   'eeg_encoder': {'eeg_encoder': 'nice',
#    'd_channels': 63,
#    'd_time': 250,
#    'd_output': 768,
#    'd_eeg': 40},
#   'embed_dim': 512,
#   'proj_dim': 256,
#   'img_size': 224,
#   'models_path': 'models',
#   'eeg_encoder_path': None,
#   'encoder_lr': 0.0003,
#   'encoder_min_lr': 1e-06,
#   'encoder_warmup_epochs': 1,
#   'encoder_delay_epochs': 0,
#   'comm_lr': 0.0003,
#   'comm_min_lr': 1e-06,
#   'comm_warmup_epochs': 1,
#   'comm_delay_epochs': 0,
#   'weight_decay': 0.01,
#   'betas': [0.9, 0.999],
#   'modules_to_train': ['eeg_encoder', 'comm'],
#   'eeg_idx': 1,
#   'img_idx': 0,
#   'prototype_idx': 2},
#  'dataset_config': {'data_path': 'data/things-eeg2',
#   'batch_size': 64,
#   'val_batch_size': None,
#   'test_batch_size': None,
#   'limit_train_size': 1.0,
#   'limit_val_size': 1.0,
#   'limit_test_size': 1.0,
#   'num_workers': None,
#   'dataset': 'things-eeg2',
#   'subs': [1],
#   'num_channels': 63,
#   'time_length': 250,
#   'preload_cache': True,
#   'img_dir': 'imgs',
#   'preprocessed_eeg_dir': 'preprocessed-eeg'}}

# %%
from brain_image.model.comm_alignment import CommAlignmentModel


model = CommAlignmentModel.load_from_checkpoint(rel_path, map_location="cpu", preload_images=False, cache_images=False)

# %%
from brain_image.model.eeg_encoder.eeg_encoder import create_eeg_encoder


eeg_cp = checkpoint["hyper_parameters"]["config"]["eeg_encoder"]
create_eeg_encoder(eeg_cp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 5
#       1 from brain_image.model.eeg_encoder.eeg_encoder import create_eeg_encoder
#       4 eeg_cp = checkpoint["hyper_parameters"]["config"]["eeg_encoder"]
# ----> 5 create_eeg_encoder(eeg_cp)
#
# File ~/dev/brain-image-implementation/src/brain_image/model/eeg_encoder/eeg_encoder.py:30, in create_eeg_encoder(config, checkpoint_path)
#      27 def create_eeg_encoder(
#      28     config: EEGEncoderConfig, checkpoint_path: Path | None = None
#      29 ) -> EEGEncoder:
# ---> 30     match config.eeg_encoder:
#      31         case "nice":
#      32             from brain_image.model.eeg_encoder.nice import NiceEEGEncoder, NiceEEGEncoderConfig
#
# AttributeError: 'dict' object has no attribute 'eeg_encoder'
