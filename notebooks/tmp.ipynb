# %%
import torch
import torchvision

torchvision.io.write_png((torch.rand(3, 64, 64) * 255).to(torch.uint8), "dummy/img.png")

# %%
import torch
from torch import nn
from torch.nn import ModuleDict

m = ModuleDict({
    "a": nn.Linear(10, 10),
})

"b" in m
# Out:
# False

# %%
import torch
a = {"s": torch.arange(3), "t": torch.arange(3)}

torch.sum(torch.stack(list(a.values())))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 import torch
#       2 a = {"s": torch.arange(3), "t": torch.arange(3)}
# ----> 4 torch.sum(torch.stack((a.values())))
#
# TypeError: stack(): argument 'tensors' (position 1) must be tuple of Tensors, not dict_values
