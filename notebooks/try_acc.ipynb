# %%
import numpy as np
import torch
from torch.nn import functional as F

from brain_image.metrics import get_top1_acc


a = torch.tensor([[0.1, 0.4, 0.2], [0.5, 0.7, -0.4]])
b = torch.tensor([
    [0.1, 0.4, 0.2], 
    [0.6, 0.7, -0.4]
    ])

a = F.normalize( a, dim=1)
b = F.normalize( b, dim=1)

Z = a @ b.T
get_top1_acc(Z)
# Out:
# tensor(1.)
