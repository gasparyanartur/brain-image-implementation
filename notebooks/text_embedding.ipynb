# %%
import torch

# %%
emb = torch.nn.Embedding(1000, 128, padding_idx=None)
x = emb(torch.arange(1000))
x.mean(), x.std()
# Out:
# (tensor(-3.5905e-05, grad_fn=<MeanBackward0>),
#  tensor(1.0017, grad_fn=<StdBackward0>))

# %%
emb(torch.tensor(1))
# Out:
# tensor([ 4.2943e-01, -7.8712e-01, -2.2161e-01, -4.8069e-02, -9.5031e-01,
#          3.0708e-01,  1.1121e+00, -1.4591e-01, -1.8161e+00, -3.9074e-01,
#          8.0808e-01, -5.5988e-01,  3.7205e-02, -1.2808e+00,  7.5802e-01,
#          6.2177e-01,  2.5823e-01,  1.4851e+00, -8.7214e-01,  9.7785e-01,
#         -3.1978e-01, -1.3991e+00, -6.7203e-02,  8.3572e-01, -2.4691e+00,
#          1.2076e+00,  9.9611e-02, -1.1700e-01, -5.6421e-01,  5.1358e-01,
#         -9.3943e-01,  1.6177e+00, -2.3289e-01,  1.8930e+00, -2.1248e-01,
#         -4.6554e-01, -5.0041e-04,  1.7662e+00,  3.9053e-01,  4.8693e-01,
#         -3.1481e-01,  4.0036e-01,  2.3436e-01, -4.2649e-01, -1.1070e+00,
#         -7.4678e-01,  2.4506e-01,  8.3315e-02,  7.2192e-01, -1.4423e+00,
#         -5.0709e-01, -2.0773e-01,  1.0828e-01, -7.9841e-01,  3.8733e-01,
#         -3.3590e-01,  5.6441e-01,  1.7863e-01, -9.8019e-01,  3.2904e-01,
#         -6.0339e-02, -7.0822e-01,  1.8401e+00,  1.1095e+00, -1.5773e+00,
# ...

# %%
s = torch.nn.ParameterDict({"0": torch.nn.Linear(3, 5)})
