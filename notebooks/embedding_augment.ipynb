# %%
from brain_image.data.tensorcache import TensorCache
import torch
from pathlib import Path

# %%
tensor_cache = TensorCache()
# Out:
# /home/gasparyanartur/dev/brain-image-implementation/.venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
#img_paths = ["data/things-eeg2/imgs/training_images/00001_aardvark/aardvark_01b.jpg", "data/things-eeg2/imgs/training_images/00001_aardvark/aardvark_02s.jpg", "data/things-eeg2/imgs/training_images/00002_abacus/abacus_01b.jpg"]

from brain_image.data.io import get_image_paths


img_paths = get_image_paths(Path("data/things-eeg2/imgs"), "train")

latents = torch.stack([tensor_cache.get_latent(p, "unaligned_synclr_vitb16", "train") for p in img_paths])
latents.shape
# Out:
# torch.Size([16540, 768])

# %%
from sklearn.decomposition import PCA


pca_100 = PCA(n_components=100)

lowdim = pca_100.fit_transform(latents.numpy())

# %%
low_dim.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 low_dim.shape
#
# NameError: name 'low_dim' is not defined
