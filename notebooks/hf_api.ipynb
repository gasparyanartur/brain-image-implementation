# %%
from huggingface_hub import HfApi

api = HfApi()

repo_id = "gasparyanartur/things-eeg2"
repo_type = "dataset"

folders = [f"sub-{sub:02}" for sub in range(1,11)]
print(folders)

api.list_repo_files(repo_id=repo_id, repo_type=repo_type)
# Out:
# ['sub-01', 'sub-02', 'sub-03', 'sub-04', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10']
# ['.gitattributes',
#  'README.md',
#  'raw-eeg/sub-01.zip',
#  'sub-01/ses-01/raw_eeg_test.npy',
#  'sub-01/ses-01/raw_eeg_training.npy',
#  'sub-01/ses-02/raw_eeg_test.npy',
#  'sub-01/ses-02/raw_eeg_training.npy',
#  'sub-01/ses-03/raw_eeg_test.npy',
#  'sub-01/ses-03/raw_eeg_training.npy',
#  'sub-01/ses-04/raw_eeg_test.npy',
#  'sub-01/ses-04/raw_eeg_training.npy',
#  'sub-02/ses-01/raw_eeg_test.npy',
#  'sub-02/ses-01/raw_eeg_training.npy',
#  'sub-02/ses-02/raw_eeg_test.npy',
#  'sub-02/ses-02/raw_eeg_training.npy',
#  'sub-02/ses-03/raw_eeg_test.npy',
#  'sub-02/ses-03/raw_eeg_training.npy',
#  'sub-02/ses-04/raw_eeg_test.npy',
#  'sub-02/ses-04/raw_eeg_training.npy',
#  'sub-03/ses-01/raw_eeg_test.npy',
#  'sub-03/ses-01/raw_eeg_training.npy',
#  'sub-03/ses-02/raw_eeg_test.npy',
#  'sub-03/ses-02/raw_eeg_training.npy',
#  'sub-03/ses-03/raw_eeg_test.npy',
#  'sub-03/ses-03/raw_eeg_training.npy',
#  'sub-03/ses-04/raw_eeg_test.npy',
#  'sub-03/ses-04/raw_eeg_training.npy',
#  'sub-04/ses-01/raw_eeg_test.npy',
#  'sub-04/ses-01/raw_eeg_training.npy',
#  'sub-04/ses-02/raw_eeg_test.npy',
#  'sub-04/ses-02/raw_eeg_training.npy',
#  'sub-04/ses-03/raw_eeg_test.npy',
#  'sub-04/ses-03/raw_eeg_training.npy',
#  'sub-04/ses-04/raw_eeg_test.npy',
#  'sub-04/ses-04/raw_eeg_training.npy',
#  'sub-05/ses-01/raw_eeg_test.npy',
#  'sub-05/ses-01/raw_eeg_training.npy',
#  'sub-05/ses-02/raw_eeg_test.npy',
#  'sub-05/ses-02/raw_eeg_training.npy',
#  'sub-05/ses-03/raw_eeg_test.npy',
#  'sub-05/ses-03/raw_eeg_training.npy',
#  'sub-05/ses-04/raw_eeg_test.npy',
#  'sub-05/ses-04/raw_eeg_training.npy',
#  'sub-06/ses-01/raw_eeg_test.npy',
#  'sub-06/ses-01/raw_eeg_training.npy',
#  'sub-06/ses-02/raw_eeg_test.npy',
#  'sub-06/ses-02/raw_eeg_training.npy',
#  'sub-06/ses-03/raw_eeg_test.npy',
#  'sub-06/ses-03/raw_eeg_training.npy',
#  'sub-06/ses-04/raw_eeg_test.npy',
#  'sub-06/ses-04/raw_eeg_training.npy',
#  'sub-07/ses-01/raw_eeg_test.npy',
#  'sub-07/ses-01/raw_eeg_training.npy',
#  'sub-07/ses-02/raw_eeg_test.npy',
#  'sub-07/ses-02/raw_eeg_training.npy',
#  'sub-07/ses-03/raw_eeg_test.npy',
#  'sub-07/ses-03/raw_eeg_training.npy',
#  'sub-07/ses-04/raw_eeg_test.npy',
#  'sub-07/ses-04/raw_eeg_training.npy',
#  'sub-08/ses-01/raw_eeg_test.npy',
#  'sub-08/ses-01/raw_eeg_training.npy',
#  'sub-08/ses-02/raw_eeg_test.npy',
#  'sub-08/ses-02/raw_eeg_training.npy',
#  'sub-08/ses-03/raw_eeg_test.npy',
#  'sub-08/ses-03/raw_eeg_training.npy',
#  'sub-08/ses-04/raw_eeg_test.npy',
#  'sub-08/ses-04/raw_eeg_training.npy',
#  'sub-09/ses-01/raw_eeg_test.npy',
#  'sub-09/ses-01/raw_eeg_training.npy',
#  'sub-09/ses-02/raw_eeg_test.npy',
#  'sub-09/ses-02/raw_eeg_training.npy',
#  'sub-09/ses-03/raw_eeg_test.npy',
#  'sub-09/ses-03/raw_eeg_training.npy',
#  'sub-09/ses-04/raw_eeg_test.npy',
#  'sub-09/ses-04/raw_eeg_training.npy',
#  'sub-10/ses-01/raw_eeg_test.npy',
#  'sub-10/ses-01/raw_eeg_training.npy',
#  'sub-10/ses-02/raw_eeg_test.npy',
#  'sub-10/ses-02/raw_eeg_training.npy',
#  'sub-10/ses-03/raw_eeg_test.npy',
#  'sub-10/ses-03/raw_eeg_training.npy',
#  'sub-10/ses-04/raw_eeg_test.npy',
#  'sub-10/ses-04/raw_eeg_training.npy']

# %%
from huggingface_hub import CommitOperationCopy, CommitOperationDelete


def copy_huggingface_folder(repo_id, repo_type, src_folder, dst_folder):
    ops = []
    files = api.list_repo_files(repo_id=repo_id, repo_type=repo_type)
    for file in files:
        if file.startswith(src_folder):
            dst_file = file.replace(src_folder, dst_folder)
            
            ops.extend([
                CommitOperationCopy(src_path_in_repo=file, path_in_repo=dst_file),
                CommitOperationDelete(path_in_repo=file)
            ])  
            print(f"Moved: {file} to {dst_file}")


    api.create_commit(
        repo_id=repo_id,
        repo_type=repo_type,
        operations=ops,
        commit_message=f"Moved {src_folder} to {dst_folder}"
    )
    

for i in range(1, 11):
    copy_huggingface_folder(repo_id, repo_type, f"sub-{i:02}", f"raw-eeg/sub-{i:02}")
# Out:
# Moved: sub-02/ses-01/raw_eeg_test.npy to raw-eeg/sub-02/ses-01/raw_eeg_test.npy
# Moved: sub-02/ses-01/raw_eeg_training.npy to raw-eeg/sub-02/ses-01/raw_eeg_training.npy
# Moved: sub-02/ses-02/raw_eeg_test.npy to raw-eeg/sub-02/ses-02/raw_eeg_test.npy
# Moved: sub-02/ses-02/raw_eeg_training.npy to raw-eeg/sub-02/ses-02/raw_eeg_training.npy
# Moved: sub-02/ses-03/raw_eeg_test.npy to raw-eeg/sub-02/ses-03/raw_eeg_test.npy
# Moved: sub-02/ses-03/raw_eeg_training.npy to raw-eeg/sub-02/ses-03/raw_eeg_training.npy
# Moved: sub-02/ses-04/raw_eeg_test.npy to raw-eeg/sub-02/ses-04/raw_eeg_test.npy
# Moved: sub-02/ses-04/raw_eeg_training.npy to raw-eeg/sub-02/ses-04/raw_eeg_training.npy
# Moved: sub-03/ses-01/raw_eeg_test.npy to raw-eeg/sub-03/ses-01/raw_eeg_test.npy
# Moved: sub-03/ses-01/raw_eeg_training.npy to raw-eeg/sub-03/ses-01/raw_eeg_training.npy
# Moved: sub-03/ses-02/raw_eeg_test.npy to raw-eeg/sub-03/ses-02/raw_eeg_test.npy
# Moved: sub-03/ses-02/raw_eeg_training.npy to raw-eeg/sub-03/ses-02/raw_eeg_training.npy
# Moved: sub-03/ses-03/raw_eeg_test.npy to raw-eeg/sub-03/ses-03/raw_eeg_test.npy
# Moved: sub-03/ses-03/raw_eeg_training.npy to raw-eeg/sub-03/ses-03/raw_eeg_training.npy
# Moved: sub-03/ses-04/raw_eeg_test.npy to raw-eeg/sub-03/ses-04/raw_eeg_test.npy
# Moved: sub-03/ses-04/raw_eeg_training.npy to raw-eeg/sub-03/ses-04/raw_eeg_training.npy
# Moved: sub-04/ses-01/raw_eeg_test.npy to raw-eeg/sub-04/ses-01/raw_eeg_test.npy
# Moved: sub-04/ses-01/raw_eeg_training.npy to raw-eeg/sub-04/ses-01/raw_eeg_training.npy
# Moved: sub-04/ses-02/raw_eeg_test.npy to raw-eeg/sub-04/ses-02/raw_eeg_test.npy
# Moved: sub-04/ses-02/raw_eeg_training.npy to raw-eeg/sub-04/ses-02/raw_eeg_training.npy
# Moved: sub-04/ses-03/raw_eeg_test.npy to raw-eeg/sub-04/ses-03/raw_eeg_test.npy
# Moved: sub-04/ses-03/raw_eeg_training.npy to raw-eeg/sub-04/ses-03/raw_eeg_training.npy
# Moved: sub-04/ses-04/raw_eeg_test.npy to raw-eeg/sub-04/ses-04/raw_eeg_test.npy
# Moved: sub-04/ses-04/raw_eeg_training.npy to raw-eeg/sub-04/ses-04/raw_eeg_training.npy
# Moved: sub-05/ses-01/raw_eeg_test.npy to raw-eeg/sub-05/ses-01/raw_eeg_test.npy
# Moved: sub-05/ses-01/raw_eeg_training.npy to raw-eeg/sub-05/ses-01/raw_eeg_training.npy
# Moved: sub-05/ses-02/raw_eeg_test.npy to raw-eeg/sub-05/ses-02/raw_eeg_test.npy
# Moved: sub-05/ses-02/raw_eeg_training.npy to raw-eeg/sub-05/ses-02/raw_eeg_training.npy
# Moved: sub-05/ses-03/raw_eeg_test.npy to raw-eeg/sub-05/ses-03/raw_eeg_test.npy
# Moved: sub-05/ses-03/raw_eeg_training.npy to raw-eeg/sub-05/ses-03/raw_eeg_training.npy
# Moved: sub-05/ses-04/raw_eeg_test.npy to raw-eeg/sub-05/ses-04/raw_eeg_test.npy
# Moved: sub-05/ses-04/raw_eeg_training.npy to raw-eeg/sub-05/ses-04/raw_eeg_training.npy
# Moved: sub-06/ses-01/raw_eeg_test.npy to raw-eeg/sub-06/ses-01/raw_eeg_test.npy
# Moved: sub-06/ses-01/raw_eeg_training.npy to raw-eeg/sub-06/ses-01/raw_eeg_training.npy
# Moved: sub-06/ses-02/raw_eeg_test.npy to raw-eeg/sub-06/ses-02/raw_eeg_test.npy
# Moved: sub-06/ses-02/raw_eeg_training.npy to raw-eeg/sub-06/ses-02/raw_eeg_training.npy
# Moved: sub-06/ses-03/raw_eeg_test.npy to raw-eeg/sub-06/ses-03/raw_eeg_test.npy
# Moved: sub-06/ses-03/raw_eeg_training.npy to raw-eeg/sub-06/ses-03/raw_eeg_training.npy
# Moved: sub-06/ses-04/raw_eeg_test.npy to raw-eeg/sub-06/ses-04/raw_eeg_test.npy
# Moved: sub-06/ses-04/raw_eeg_training.npy to raw-eeg/sub-06/ses-04/raw_eeg_training.npy
# Moved: sub-07/ses-01/raw_eeg_test.npy to raw-eeg/sub-07/ses-01/raw_eeg_test.npy
# Moved: sub-07/ses-01/raw_eeg_training.npy to raw-eeg/sub-07/ses-01/raw_eeg_training.npy
# Moved: sub-07/ses-02/raw_eeg_test.npy to raw-eeg/sub-07/ses-02/raw_eeg_test.npy
# Moved: sub-07/ses-02/raw_eeg_training.npy to raw-eeg/sub-07/ses-02/raw_eeg_training.npy
# Moved: sub-07/ses-03/raw_eeg_test.npy to raw-eeg/sub-07/ses-03/raw_eeg_test.npy
# Moved: sub-07/ses-03/raw_eeg_training.npy to raw-eeg/sub-07/ses-03/raw_eeg_training.npy
# Moved: sub-07/ses-04/raw_eeg_test.npy to raw-eeg/sub-07/ses-04/raw_eeg_test.npy
# Moved: sub-07/ses-04/raw_eeg_training.npy to raw-eeg/sub-07/ses-04/raw_eeg_training.npy
# Moved: sub-08/ses-01/raw_eeg_test.npy to raw-eeg/sub-08/ses-01/raw_eeg_test.npy
# Moved: sub-08/ses-01/raw_eeg_training.npy to raw-eeg/sub-08/ses-01/raw_eeg_training.npy
# Moved: sub-08/ses-02/raw_eeg_test.npy to raw-eeg/sub-08/ses-02/raw_eeg_test.npy
# Moved: sub-08/ses-02/raw_eeg_training.npy to raw-eeg/sub-08/ses-02/raw_eeg_training.npy
# Moved: sub-08/ses-03/raw_eeg_test.npy to raw-eeg/sub-08/ses-03/raw_eeg_test.npy
# Moved: sub-08/ses-03/raw_eeg_training.npy to raw-eeg/sub-08/ses-03/raw_eeg_training.npy
# Moved: sub-08/ses-04/raw_eeg_test.npy to raw-eeg/sub-08/ses-04/raw_eeg_test.npy
# Moved: sub-08/ses-04/raw_eeg_training.npy to raw-eeg/sub-08/ses-04/raw_eeg_training.npy
# Moved: sub-09/ses-01/raw_eeg_test.npy to raw-eeg/sub-09/ses-01/raw_eeg_test.npy
# Moved: sub-09/ses-01/raw_eeg_training.npy to raw-eeg/sub-09/ses-01/raw_eeg_training.npy
# Moved: sub-09/ses-02/raw_eeg_test.npy to raw-eeg/sub-09/ses-02/raw_eeg_test.npy
# Moved: sub-09/ses-02/raw_eeg_training.npy to raw-eeg/sub-09/ses-02/raw_eeg_training.npy
# Moved: sub-09/ses-03/raw_eeg_test.npy to raw-eeg/sub-09/ses-03/raw_eeg_test.npy
# Moved: sub-09/ses-03/raw_eeg_training.npy to raw-eeg/sub-09/ses-03/raw_eeg_training.npy
# Moved: sub-09/ses-04/raw_eeg_test.npy to raw-eeg/sub-09/ses-04/raw_eeg_test.npy
# Moved: sub-09/ses-04/raw_eeg_training.npy to raw-eeg/sub-09/ses-04/raw_eeg_training.npy
# Moved: sub-10/ses-01/raw_eeg_test.npy to raw-eeg/sub-10/ses-01/raw_eeg_test.npy
# Moved: sub-10/ses-01/raw_eeg_training.npy to raw-eeg/sub-10/ses-01/raw_eeg_training.npy
# Moved: sub-10/ses-02/raw_eeg_test.npy to raw-eeg/sub-10/ses-02/raw_eeg_test.npy
# Moved: sub-10/ses-02/raw_eeg_training.npy to raw-eeg/sub-10/ses-02/raw_eeg_training.npy
# Moved: sub-10/ses-03/raw_eeg_test.npy to raw-eeg/sub-10/ses-03/raw_eeg_test.npy
# Moved: sub-10/ses-03/raw_eeg_training.npy to raw-eeg/sub-10/ses-03/raw_eeg_training.npy
# Moved: sub-10/ses-04/raw_eeg_test.npy to raw-eeg/sub-10/ses-04/raw_eeg_test.npy
# Moved: sub-10/ses-04/raw_eeg_training.npy to raw-eeg/sub-10/ses-04/raw_eeg_training.npy
